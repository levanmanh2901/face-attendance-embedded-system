# %%
# !uv pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.4.21 🚀 Python-3.12.12 torch-2.10.0+cu128 CUDA:0 (NVIDIA H100 80GB HBM3, 81079MiB)
# Setup complete ✅ (26 CPUs, 230.0 GB RAM, 43.5/235.7 GB disk)

# %%
# !gdown 1JGvIeMNp8M87u1cqSprqh-roMh7eWlXu
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1JGvIeMNp8M87u1cqSprqh-roMh7eWlXu
# From (redirected): https://drive.google.com/uc?id=1JGvIeMNp8M87u1cqSprqh-roMh7eWlXu&confirm=t&uuid=acb1fc35-4365-46dd-9458-9566c6711fc5
# To: /content/yolo_retinaface_pose.zip
# 100% 1.84G/1.84G [00:20<00:00, 87.8MB/s]

# %%
# !unzip yolo_retinaface_pose.zip
# Out:
# Kết quả truyền trực tuyến bị cắt bớt đến 5000 dòng cuối.
#   inflating: yolo_retinaface_pose/labels/train/55_Sports_Coach_Trainer_sportcoaching_55_903.txt
#   inflating: yolo_retinaface_pose/labels/train/55_Sports_Coach_Trainer_sportcoaching_55_908.txt
#   inflating: yolo_retinaface_pose/labels/train/55_Sports_Coach_Trainer_sportcoaching_55_91.txt
#   inflating: yolo_retinaface_pose/labels/train/55_Sports_Coach_Trainer_sportcoaching_55_914.txt
#   inflating: yolo_retinaface_pose/labels/train/55_Sports_Coach_Trainer_sportcoaching_55_917.txt
#   inflating: yolo_retinaface_pose/labels/train/55_Sports_Coach_Trainer_sportcoaching_55_923.txt
#   inflating: yolo_retinaface_pose/labels/train/55_Sports_Coach_Trainer_sportcoaching_55_924.txt
#   inflating: yolo_retinaface_pose/labels/train/55_Sports_Coach_Trainer_sportcoaching_55_925.txt
#   inflating: yolo_retinaface_pose/labels/train/55_Sports_Coach_Trainer_sportcoaching_55_931.txt
# ...

# %%
# Train YOLO26n on COCO8 for 3 epochs
# !yolo pose  train model=yolo26n-pose.pt data="/content/yolo_retinaface_pose/dataset.yaml" batch=128 epochs=20 imgsz=640

# %%
# !gdown 1b8IVKpIMEpBZENxTriKmHazfbwlEM16I
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1b8IVKpIMEpBZENxTriKmHazfbwlEM16I
# From (redirected): https://drive.google.com/uc?id=1b8IVKpIMEpBZENxTriKmHazfbwlEM16I&confirm=t&uuid=f7c07319-556b-402c-a7dc-4d4c6ab5147b
# To: /content/yolo_retinaface_pose_train_only.zip
# 100% 1.48G/1.48G [00:19<00:00, 75.2MB/s]

# %%
# !unzip yolo_retinaface_pose_train_only.zip
# Out:
# Kết quả truyền trực tuyến bị cắt bớt đến 5000 dòng cuối.
#   inflating: yolo_retinaface_pose_train_only/labels/train/44_Aerobics_Aerobics_44_533.txt
#   inflating: yolo_retinaface_pose_train_only/labels/train/44_Aerobics_Aerobics_44_543.txt
#   inflating: yolo_retinaface_pose_train_only/labels/train/44_Aerobics_Aerobics_44_547.txt
#   inflating: yolo_retinaface_pose_train_only/labels/train/44_Aerobics_Aerobics_44_551.txt
#   inflating: yolo_retinaface_pose_train_only/labels/train/44_Aerobics_Aerobics_44_554.txt
#   inflating: yolo_retinaface_pose_train_only/labels/train/44_Aerobics_Aerobics_44_558.txt
#   inflating: yolo_retinaface_pose_train_only/labels/train/44_Aerobics_Aerobics_44_56.txt
#   inflating: yolo_retinaface_pose_train_only/labels/train/44_Aerobics_Aerobics_44_567.txt
#   inflating: yolo_retinaface_pose_train_only/labels/train/44_Aerobics_Aerobics_44_57.txt
#   inflating: yolo_retinaface_pose_train_only/labels/train/44_Aerobics_Aerobics_44_570.txt
# ...

# %%
# !yolo pose  train model=yolo26n-pose.pt data="/content/yolo_retinaface_pose_train_only/dataset.yaml" batch=96 epochs=20 imgsz=640
# Out:
# Ultralytics 8.4.21 🚀 Python-3.12.12 torch-2.10.0+cu128 CUDA:0 (NVIDIA H100 80GB HBM3, 81079MiB)
# ...

# %%
# !yolo predict model="/content/runs/pose/train5/weights/best.pt" source="/content/yolo_retinaface_pose/images/val/0_Parade_Parade_0_102.jpg"
# Out:
# Ultralytics 8.4.21 🚀 Python-3.12.12 torch-2.10.0+cu128 CUDA:0 (NVIDIA H100 80GB HBM3, 81079MiB)
# YOLO26n-pose summary (fused): 132 layers, 2,494,026 parameters, 0 gradients, 5.6 GFLOPs
#
# image 1/1 /content/yolo_retinaface_pose/images/val/0_Parade_Parade_0_102.jpg: 512x640 26 faces, 102.0ms
# Speed: 2.6ms preprocess, 102.0ms inference, 15.4ms postprocess per image at shape (1, 3, 512, 640)
# Results saved to /content/runs/pose/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# !rm -rf /content/runs/pose/train4

# %%
# !cp -r /content/runs /content/drive/MyDrive/AIVIETNAM2026

# %%
# !yolo export model=/content/runs/pose/train5/weights/best.pt format=onnx
# Out:
# Ultralytics 8.4.21 🚀 Python-3.12.12 torch-2.10.0+cu128 CPU (Intel Xeon Platinum 8481C CPU @ 2.70GHz)
# 💡 ProTip: Export to OpenVINO format for best performance on Intel hardware. Learn more at https://docs.ultralytics.com/integrations/openvino/
# YOLO26n-pose summary (fused): 132 layers, 2,494,026 parameters, 0 gradients, 5.6 GFLOPs
#
# PyTorch: starting from '/content/runs/pose/train5/weights/best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 300, 21) (5.7 MB)
# requirements: Ultralytics requirements ['onnx>=1.12.0,<2.0.0', 'onnxslim>=0.1.71', 'onnxruntime'] not found, attempting AutoUpdate...
# Using Python 3.12.12 environment at: /usr
# Resolved 12 packages in 143ms
# Prepared 4 packages in 851ms
# Installed 4 packages in 177ms
#  + colorama==0.4.6
#  + onnx==1.20.1
#  + onnxruntime==1.24.3
#  + onnxslim==0.1.87
#
# requirements: AutoUpdate success ✅ 1.4s
# WARNING ⚠️ requirements: Restart runtime or rerun command for updates to take effect
#
#
# ...
